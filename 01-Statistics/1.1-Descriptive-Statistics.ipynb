# %% [markdown]
# Descriptive statistics — summarize data (center, spread, shape). Used in EDA, preprocessing, feature engineering.
#
# We start with Descriptive statistics because ML pipelines begin with cleaning and understanding data.
#
#
# Descriptive statistics — purpose in ML/AI
#
# Why descriptive stats matter for ML:
#
# Quickly judge data quality (missing values, skew, outliers).
#
# Choose preprocessing (scaling, transform, clipping).
#
# Feature selection hints (correlated features, constant features).
#
# Understand class imbalance (counts, mode).
#
# Decide modeling approach (continuous vs categorical → regression vs classification).
#
# Interpretability — communicate dataset summary to stakeholders.
#
# Examples:
#
# If feature has huge variance → scale or normalize for gradient descent.
#
# If target is highly skewed → log-transform before regression.
#
# If a column has same value for 99% → drop it (no signal).

# %% [markdown]
# 📊 Measure of Dispersion
#
# When we calculate mean, median, or mode, we know the center of the data — where most values lie.
# But we don’t know how spread out the data is. That’s where measure of dispersion comes in.
#
# 🧠 Simple Definition:
#
# A measure of dispersion tells us how much the data values vary or spread out around the mean (or any central value).
#
# 🎯 Why it’s important (especially in ML):
#
# Helps understand data consistency — whether data points are tightly packed or widely spread.
#
# Many ML models (like regression, clustering, anomaly detection) assume certain levels of variance or normal distribution.
#
# Helps detect outliers or high variability which can affect model accuracy.
#
# ⚙️ Common Measures of Dispersion:
# Measure	Meaning	Used For
# Range	Max - Min	Quick idea of spread
# Variance	Average squared deviation from the mean	Used heavily in ML (like loss functions)
# Standard Deviation (SD)	Square root of variance	Tells spread in same units as data
# Interquartile Range (IQR)	Q3 - Q1	Used to detect outliers (Box plots)
# 🧩 Real ML Example:
#
# Let’s say we have two models predicting house prices:
#
# Model A predictions: [10.1, 10.2, 10.0, 10.3]
#
# Model B predictions: [8, 12, 6, 14]
#
# Both may have the same mean, but Model A has a smaller dispersion → more stable and reliable predictions.

# %% [markdown]
# 🧍‍♂️ Population
#
# → The entire group you want to study or make conclusions about.
# It contains all possible data points.
#
# Example:
# All 10,000 students in your university.
# If you want to know the average height of students — that’s your population.
#
# 👥 Sample
#
# → A small part (subset) of the population that you actually collect data from.
# We use it because collecting data from everyone is impractical.
#
# Example:
# You randomly measure the height of 100 students from your university — that’s your sample.
#
# 💡 In short:
# Concept	Meaning	Example
# Population	Whole group	All 10,000 students
# Sample	Subset	100 students you surveyed
# 🎯 Why it matters (AI/ML context):
#
# When you train a model, your training data = sample
#
# The model should generalize to real-world data = population
#
# So, inferential stats helps you ensure your sample represents the population fairly otherwise your model will be biased.
